# %% [markdown]
# <a href="https://colab.research.google.com/github/mancunian1792/DS5220/blob/master/NeuralODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install prodict

# %%
# !pip install git+https://github.com/rtqichen/torchdiffeq.git

# %%
# !pip install -U -q PyDrive

# %%
import os
import argparse
import logging
import time
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchdiffeq import odeint as odeint
from prodict import Prodict

# %%
args = Prodict.from_dict({"network": "odenet","tol": 1e-3, "nepochs": 10000, "lr": 0.01, "batch_size": 128, "test_batch_size": 1, "gpu": 1})

# %% [markdown]
# Now, we need to import the data from google drive

# %% [markdown]
# First , importing and authenticating the drive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
train_link = "https://drive.google.com/open?id=1m84l0jLwbTuFliZZ_J5IZCY6nZvGAvFN"
test_link = "https://drive.google.com/open?id=1sf3MNvKjUDJLLQU0fIrRk_BgCkXNMywR"
submission_link = "https://drive.google.com/open?id=1c7sGKW-nzMgJqd5HSHhRNWwUdhM24art"

train_fluff, trainId = train_link.split('=')
test_fluff , testId = test_link.split('=')
subm_fluff, subId = submission_link.split('=')


train_downloaded = drive.CreateFile({"id":trainId})
test_downloaded = drive.CreateFile({"id": testId})
subm_downloaded = drive.CreateFile({"id": subId})
train_downloaded.GetContentFile('train.csv')
test_downloaded.GetContentFile('test.csv')
subm_downloaded.GetContentFile('sample_submission.csv')

# %%
class DatasetSantander(Dataset):
    
    def __init__(self, file_path, transform=None, output_col = None, test = False):
        self.data = pd.read_csv(file_path)
        self.n = self.data.shape[0]
        self.transform = transform
        self.features = [x for x in self.data.columns if x.startswith("var")]
        if output_col and test == False:
            self.y = self.data[output_col].astype(np.float32).values.reshape(-1, 1)
        else:
            self.y =  np.zeros((self.n, 1))
        if self.features:
            self.cont_X = self.data[self.features].astype(np.float32).values
        else:
            self.cont_X = np.zeros((self.n, 1))
            
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        x = self.cont_X[index]
        y = self.y[index]

        if self.transform is not None:
            x = self.transform(x)
            
        return x, y

def get_data_loaders(batch_size=128, test_batch_size=1000):
    
    transform_train = torch.tensor

    transform_test = torch.tensor

    train_loader = DataLoader(
        DatasetSantander(file_path='train.csv', transform= transform_train, output_col="target"
    ), batch_size=batch_size, shuffle=True, num_workers=2, drop_last=True)

    train_eval_loader = DataLoader(
        DatasetSantander(file_path='train.csv', transform= transform_train, output_col= "target"
    ), batch_size=batch_size, shuffle=False, num_workers=2, drop_last=True)

    test_loader = DataLoader(
        DatasetSantander(file_path='test.csv', transform= transform_test, output_col="target",
    test = True), batch_size=test_batch_size, shuffle=False, num_workers=2, drop_last=True)

    return train_loader, train_eval_loader, test_loader

# %%
class ODEfunc(nn.Module):
    def __init__(self, H):
        super(ODEfunc, self).__init__()
        self.lin1 = nn.Linear(H, H)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout(0.2)
        self.lin2 = nn.Linear(H, H)
        self.prelu = nn.PReLU(1)
        self.nfe = 0
    
    def forward(self,t,x):
        self.nfe += 1
        out = self.lin1(x)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.lin2(out)
        out = self.prelu(out)
        return out


class ODEBlock(nn.Module):

    def __init__(self, odefunc):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_time = torch.tensor([0, 1]).float()

    def forward(self, x):
        self.integration_time = self.integration_time.type_as(x)
        out = odeint(self.odefunc, x, self.integration_time, rtol=args.tol, atol=args.tol)
        return out[1]

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value


class Flatten(nn.Module):

    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val

def inf_generator(iterable):
    """Allows training with DataLoaders in a single infinite loop:
        for i, (x, y) in enumerate(inf_generator(train_loader)):
    """
    iterator = iterable.__iter__()
    while True:
        try:
            yield iterator.__next__()
        except StopIteration:
            iterator = iterable.__iter__()


def learning_rate_with_decay(batch_size, batch_denom, batches_per_epoch, boundary_epochs, decay_rates):
    initial_learning_rate = args.lr * batch_size / batch_denom

    boundaries = [int(batches_per_epoch * epoch) for epoch in boundary_epochs]
    vals = [initial_learning_rate * decay for decay in decay_rates]

    def learning_rate_fn(itr):
        lt = [itr < b for b in boundaries] + [True]
        i = np.argmax(lt)
        return vals[i]

    return learning_rate_fn


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')
print("What is device ? Is it none ?", device)
is_odenet = args.network == 'odenet'
N, D_in, H, D_out = 128, 200, 200, 1
feature_layers = [ODEBlock(ODEfunc(H))] if is_odenet else [ResBlock(128, 128) for _ in range(6)]
fc_layers = [nn.Linear(H, D_out), nn.Sigmoid()]
model = nn.Sequential(*feature_layers, *fc_layers).to("cuda")
print('Number of parameters: {}'.format(count_parameters(model)))
model.cuda()
criterion = nn.BCELoss().to(device.type)

train_loader, train_eval_loader, test_loader = get_data_loaders(args.batch_size, args.test_batch_size)
data_gen = inf_generator(train_loader)
batches_per_epoch = len(train_loader)
optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
best_acc = 0
for itr in range(args.nepochs):
    print("In iter ::", itr)
    optimizer.zero_grad()
    x, y = data_gen.__next__()
    x = x.to(device.type)
    y = y.to(device.type)
    logits = model(x)
    loss = criterion(logits, y)
    print("Loss is", loss)
    loss.backward()
    optimizer.step()
# Out:
# What is device ? Is it none ? cuda:1
# Number of parameters: 80602
# In iter :: 0
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Loss is tensor(0.9625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 1
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 3
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 4
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 5
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 6
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 7
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 8
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 9
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 10
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 11
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 12
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 13
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 14
# Loss is tensor(4.9649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 15
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 16
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 17
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 18
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 19
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 20
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 21
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 22
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 23
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 24
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 25
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 26
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 27
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 28
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 29
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 30
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 31
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 32
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 33
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 34
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 35
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 36
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 37
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 38
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 39
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 40
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 41
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 42
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 43
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 44
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 45
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 46
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 47
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 48
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 49
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 50
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 51
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 52
# Loss is tensor(1.2952, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 53
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 54
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 55
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 56
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 57
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 58
# Loss is tensor(1.2952, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 59
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 60
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 61
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 62
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 63
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 64
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 65
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 66
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 67
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 68
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 69
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 70
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 71
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 72
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 73
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 74
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 75
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 76
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 77
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 78
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 79
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 80
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 81
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 82
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 83
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 84
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 85
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 86
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 87
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 88
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 89
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 90
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 91
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 92
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 93
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 94
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 95
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 96
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 97
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 98
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 99
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 100
# Loss is tensor(4.5332, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 101
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 102
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 103
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 104
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 105
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 106
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 107
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 108
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 109
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 110
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 111
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 112
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 113
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 114
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 115
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 116
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 117
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 118
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 119
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 120
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 121
# Loss is tensor(4.1015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 122
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 123
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 124
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 125
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 126
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 127
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 128
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 129
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 130
# Loss is tensor(4.3173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter ::
, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 486
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 487
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 488
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 489
# Loss is tensor(1.2952, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 490
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 491
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 492
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 493
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 494
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 495
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 496
# Loss is tensor(4.9649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 497
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 498
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 499
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 500
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 501
# Loss is tensor(1.2952, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 502
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 503
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 504
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 505
# ...
# In iter :: 2133
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2134
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2135
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2136
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2137
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2138
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2139
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2140
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2141
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2142
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2143
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2144
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2145
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2146
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2147
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2148
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2149
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2150
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2151
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2152
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2153
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2154
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2155
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2156
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2157
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2158
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2159
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2160
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2161
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2162
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2163
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2164
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2165
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2166
# Loss is tensor(4.3173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2167
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2168
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2169
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2170
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2171
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2172
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2173
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2174
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2175
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2176
# Loss is tensor(5.3967, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2177
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2178
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2179
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2180
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2181
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2182
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2183
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2184
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2185
# Loss is tensor(1.0793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2186
# Loss is tensor(1.0793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2187
# Loss is tensor(1.0793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2188
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2189
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2190
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2191
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2192
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2193
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2194
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2195
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2196
# Loss is tensor(4.1015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2197
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2198
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2199
# Loss is tensor(4.1015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2200
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2201
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2202
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2203
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2204
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2205
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2206
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2207
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2208
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2209
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2210
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2211
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2212
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2213
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2214
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2215
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2216
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2217
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2218
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2219
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2220
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2221
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2222
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2223
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2224
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2225
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2226
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2227
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2228
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2229
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2230
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2231
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2232
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2233
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2234
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2235
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2236
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2237
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2238
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2239
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2240
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2241
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2242
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2243
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2244
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2245
# Loss is tensor(1.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2246
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2247
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2248
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2249
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2250
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2251
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2252
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2253
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2254
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2255
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2256
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2257
# Loss is tensor(3.6697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2258
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2259
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2260
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2261
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2262
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2263
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2264
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2265
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2266
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2267
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2268
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2269
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2270
# Loss is tensor(5.3967, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2271
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2272
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2273
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2274
# Loss is tensor(5.6126, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2275
# Loss is tensor(3.8856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2276
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2277
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2278
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2279
# Loss is tensor(4.3173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2280
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2281
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2282
# Loss is tensor(3.2380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2283
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2284
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2285
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2286
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2287
# Loss is tensor(1.5111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2288
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2289
# Loss is tensor(1.9428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2290
# Loss is tensor(4.3173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2291
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2292
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2293
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2294
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2295
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2296
# Loss is tensor(2.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2297
# Loss is tensor(3.4539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2298
# Loss is tensor(2.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2299
# Loss is tensor(3.0221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2300
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2301
# Loss is tensor(2.5904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2302
# Loss is tensor(2.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# In iter :: 2303

# %%
+device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')
print("What is device ? Is it none ?", device)

# %%
import gc
gc.collect()
# Out:
# 0

# %%
test_data = pd.read_csv('test.csv')
ID_Code = test_data["ID_code"]
test_x = pd.DataFrame(test_data.drop(["ID_code"], axis=1)).reset_index(drop=True)

# %%
from torch.autograd import Variable

# %%
test_x_torch = Variable(torch.from_numpy(test_x.values).float(), requires_grad = False).to("cuda")

# %%
pred = model(test_x_torch[0:100])

# %%
predictions = []
for i in range(0, len(test_loader)):
  pred = model(test_x_torch[i])
  predictions.append(pred.cpu().detach().numpy())
allP = flatten(predictions)
len(allP)
submissions = pd.read_csv('sample_submission.csv')
submissions['target'] = allP
submissions.to_csv('neuralode.csv')
print("All Done.")
# Out:
# 200000

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
# Out:
# Requirement already satisfied: gputil in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)

# %%
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Gen RAM Free: 7.3 GB  | Proc size: 9.7 GB
# GPU RAM Free: 13832MB | Used: 1247MB | Util   8% | Total 15079MB

# %%
def flatten(listOfLists):
    "Flatten one level of nesting"
    return list(chain.from_iterable(listOfLists))

# %%
from itertools import chain

# %%
from google.colab import files

# %%
files.download('neuralode.csv')
